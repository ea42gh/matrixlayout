# %% [markdown]
# # Eigen/SVD table
# Render an eigenproblem table as SVG.

# %%
import sympy as sym
from IPython.display import SVG, display
from la_figures import eig_tbl_spec
from matrixlayout import eigproblem_svg

A = sym.Matrix([[2, 0], [0, 3]])
spec = eig_tbl_spec(A)
svg = eigproblem_svg(spec, case="S")
display(SVG(svg))
