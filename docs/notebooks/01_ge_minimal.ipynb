# %% [markdown]
# # GE minimal
# Render a small GE grid as SVG.

# %%
import sympy as sym
from IPython.display import SVG, display
from matrixlayout.ge import ge_grid_svg

matrices = [[None, sym.Matrix([[1, 2], [3, 4]])]]
svg = ge_grid_svg(matrices=matrices)
display(SVG(svg))
