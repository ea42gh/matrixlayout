# %% [markdown]
# # Backsubstitution (matrixlayout.backsubst)
#
# This notebook introduces backsubstitution renderers.

# %% [markdown]
# ## `backsubst_tex`
# Emit LaTeX for system/cascade/solution blocks.

# %%
from matrixlayout.backsubst import backsubst_tex

tex = backsubst_tex(
    system_txt=r"x_1 + x_2 = 1",
    cascade_txt=r"x_2 = 1",
    solution_txt=r"x = (0,1)",
)
tex[:200]
# Out:
# '\\documentclass[fleqn,notitlepage,table,svgnames]{article}\n\\setlength{\\mathindent}{0pt}\n\\pagestyle{empty}\n\n% Make the canvas very large; jupyter_tikz will crop the final SVG.\n\\usepackage[margin=0cm,pap'

# %% [markdown]
# ## `backsubst_svg`
# Render backsubstitution to SVG.

# %%
from matrixlayout.backsubst import backsubst_svg

svg = backsubst_svg(
    system_txt=r"x_1 + x_2 = 1",
    cascade_txt=r"x_2 = 1",
    solution_txt=r"x = (0,1)",
)
svg[:200]
# Out:
# ---------------------------------------------------------------------------
# RenderError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 from matrixlayout.backsubst import backsubst_svg
# ----> 3 svg = backsubst_svg(
#       4     system_txt=r"x_1 + x_2 = 1",
#       5     cascade_txt=r"x_2 = 1",
#       6     solution_txt=r"x = (0,1)",
#       7 )
#       8 svg[:200]
#
# File /opt/ea42gh/matrixlayout/matrixlayout/backsubst.py:207, in backsubst_svg(preamble, system_txt, cascade_txt, cascade_trace, solution_txt, show_system, show_cascade, show_solution, fig_scale, decorators, strict, toolchain_name, crop, padding, frame, exact_bbox, output_stem, tmp_dir, output_dir, render_opts)
#     205 if exact_bbox is not None:
#     206     opts["exact_bbox"] = exact_bbox
# --> 207 return render_svg(tex, **opts)
#
# File /opt/ea42gh/matrixlayout/matrixlayout/render.py:123, in render_svg(tex_source, toolchain_name, output_stem, crop, padding, frame, exact_bbox, output_dir)
#     121 tmp = Path(tempfile.mkdtemp(prefix="matrixlayout_render_"))
#     122 try:
# --> 123     artifacts = render_svg_with_artifacts(
#     124         tex_source,
#     125         output_dir=tmp,
#     126         toolchain_name=toolchain_name,
#     127         output_stem=output_stem,
#     128         crop=crop,
#     129         padding=padding,
#     130         frame=frame,
#     131         exact_bbox=exact_bbox,
#     132     )
#     133     svg_text = _strip_svg_header_comment(artifacts.read_svg())
#     134 except Exception:
#     135     # Keep tmp directory for inspection on failure.
#
# File /opt/ea42gh/matrixlayout/matrixlayout/render.py:71, in render_svg_with_artifacts(tex_source, output_dir, toolchain_name, output_stem, crop, padding, frame, exact_bbox)
#      68 outdir = Path(output_dir)
#      69 outdir.mkdir(parents=True, exist_ok=True)
# ---> 71 return jupyter_tikz.render_svg_with_artifacts(
#      72     tex_source,
#      73     output_dir=outdir,
#      74     toolchain_name=toolchain_name,
#      75     output_stem=output_stem,
#      76     crop=crop,
#      77     padding=padding,
#      78     frame=frame,
#      79     exact_bbox=exact_bbox,
#      80 )
#
# File /opt/ea42gh/jupyter-tikz/jupyter_tikz/executor.py:341, in render_svg_with_artifacts(tex_source, output_dir, toolchain_name, output_stem, crop, padding, frame, exact_bbox)
#     329 artifacts = _run_toolchain_in_dir(
#     330     tc,
#     331     tex_source,
#    (...)    337     padding=pad,
#     338 )
#     340 if not artifacts.returncodes or artifacts.returncodes[-1] != 0:
# --> 341     raise RenderError(
#     342         _format_toolchain_failure(
#     343             artifacts,
#     344             workdir=Path(output_dir),
#     345             output_stem=output_stem,
#     346         )
#     347     )
#     349 if artifacts.svg_path is None:
#     350     raise RenderError(
#     351         "SVG output not produced.\n"
#     352         f"Artifacts kept at: {Path(output_dir)}."
#     353     )
#
# RenderError: Toolchain execution failed.
# Artifacts kept at: /tmp/matrixlayout_render_kndnujfy.
# See stderr at: /tmp/matrixlayout_render_kndnujfy/output.stderr.txt
# Last returncode: 12.
# ---- stderr tail ----
# Latexmk: If appropriate, the -f option can be used to get latexmk
#   to try to force complete processing.
#
#
# ---- latex log tail ----
# dimen267
# \pgf@sys@shading@range@num=\count293
# \pgf@shadingcount=\count294
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreimage.code.tex
# File: pgfcoreimage.code.tex 2023-01-15 v3.1.10 (3.1.10)
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoreexternal.code.
# tex
# File: pgfcoreexternal.code.tex 2023-01-15 v3.1.10 (3.1.10)
# \pgfexternal@startupbox=\box62
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorelayers.code.te
# x
# File: pgfcorelayers.code.tex 2023-01-15 v3.1.10 (3.1.10)
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcoretransparency.c
# ode.tex
# File: pgfcoretransparency.code.tex 2023-01-15 v3.1.10 (3.1.10)
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorepatterns.code.
# tex
# File: pgfcorepatterns.code.tex 2023-01-15 v3.1.10 (3.1.10)
# )
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/basiclayer/pgfcorerdf.code.tex
# File: pgfcorerdf.code.tex 2023-01-15 v3.1.10 (3.1.10)
# )))
# (/usr/share/texlive/texmf-dist/tex/generic/pgf/modules/pgfmoduleshapes.code.tex
# File: pgfmoduleshapes.code.tex 2023-01-15 v3.1.10 (3.1.10)
# \pgfnodeparttextbox=\box63
# )
# Package: nicematrix 2022/12/12 v6.13e Enhanced arrays with the help of PGF/TikZ
#
# \g__nicematrix_env_int=\count295
# \g__nicematrix_NiceMatrixBlock_int=\count296
# \l__nicematrix_note_in_caption_int=\count297
# \l__nicematrix_columns_width_dim=\dimen268
# \l__nicematrix_col_width_dim=\dimen269
# \g__nicematrix_row_total_int=\count298
# \g__nicematrix_col_total_int=\count299
# \g__nicematrix_last_row_node_int=\count300
# \l__nicematrix_key_nb_rows_int=\count301
# \g__nicematrix_blocks_wd_dim=\dimen270
# \g__nicematrix_blocks_ht_dim=\dimen271
# \g__nicematrix_blocks_dp_dim=\dimen272
# \l__nicematrix_width_dim=\dimen273
# \l__nicematrix_tabular_width_dim=\dimen274
# \l__nicematrix_rule_width_dim=\dimen275
# \l__nicematrix_old_iRow_int=\count302
# \l__nicematrix_old_jCol_int=\count303
# \g__nicematrix_total_X_weight_int=\count304
# \l__nicematrix_X_columns_dim=\dimen276
# \l__nicematrix_x_initial_dim=\dimen277
# \l__nicematrix_y_initial_dim=\dimen278
# \l__nicematrix_x_final_dim=\dimen279
# \l__nicematrix_y_final_dim=\dimen280
# \l__nicematrix_tmpc_dim=\dimen281
# \l__nicematrix_tmpd_dim=\dimen282
# \g__nicematrix_width_last_col_dim=\dimen283
# \g__nicematrix_width_first_col_dim=\dimen284
# \l__nicematrix_row_min_int=\count305
# \l__nicematrix_row_max_int=\count306
# \l__nicematrix_col_min_int=\count307
# \l__nicematrix_col_max_int=\count308
# \g__nicematrix_static_num_of_col_int=\count309
# \l__nicematrix_rounded_corners_dim=\dimen285
# \l__nicematrix_line_width_dim=\dimen286
# \g__nicematrix_block_box_int=\count310
# \l__nicematrix_submatrix_extra_height_dim=\dimen287
# \l__nicematrix_submatrix_left_xshift_dim=\dimen288
# \l__nicematrix_submatrix_right_xshift_dim=\dimen289
# \l__nicematrix_first_row_int=\count311
# \l__nicematrix_first_col_int=\count312
# \l__nicematrix_last_row_int=\count313
# \l__nicematrix_last_col_int=\count314
# \c@tabularnote=\count315
# \c@nicematrix_draft=\count316
# \l__nicematrix_cell_space_top_limit_dim=\dimen290
# \l__nicematrix_cell_space_bottom_limit_dim=\dimen291
# \l__nicematrix_xdots_inter_dim=\dimen292
# \l__nicematrix_xdots_shorten_start_dim=\dimen293
# \l__nicematrix_xdots_shorten_end_dim=\dimen294
# \l__nicematrix_xdots_radius_dim=\dimen295
# \l__nicematrix_notes_above_space_dim=\dimen296
# \l__nicematrix_left_margin_dim=\dimen297
# \l__nicematrix_right_margin_dim=\dimen298
# \l__nicematrix_extra_left_margin_dim=\dimen299
# \l__nicematrix_extra_right_margin_dim=\dimen300
# \c__nicematrix_max_l_dim=\dimen301
# \l__nicematrix_position_int=\count317
# \l__nicematrix_start_int=\count318
# \l__nicematrix_multiplicity_int=\count319
# \l__nicematrix_brace_yshift_dim=\dimen302
# ) (./output.aux)
# \openout1 = `output.aux'.
#
# LaTeX Font Info:    Checking defaults for OML/cmm/m/it on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for OMS/cmsy/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for OT1/cmr/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for T1/cmr/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for TS1/cmr/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for OMX/cmex/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
# LaTeX Font Info:    Checking defaults for U/cmr/m/n on input line 16.
# LaTeX Font Info:    ... okay on input line 16.
#
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# *geometry* verbose mode - [ preamble ] result:
# * driver: pdftex
# * paper: custom
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(0.0pt, 6504.29999pt, 0.0pt)
# * v-part:(T,H,B)=(0.0pt, 6504.29999pt, 0.0pt)
# * \paperwidth=6504.29999pt
# * \paperheight=6504.29999pt
# * \textwidth=6504.29999pt
# * \textheight=6504.29999pt
# * \oddsidemargin=-72.26999pt
# * \evensidemargin=-72.26999pt
# * \topmargin=-109.26999pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=10.0pt
# * \footskip=30.0pt
# * \marginparwidth=65.0pt
# * \marginparsep=11.0pt
# * \columnsep=10.0pt
# * \skip\footins=9.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# (/usr/share/texlive/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# \scratchcounter=\count320
# \scratchdimen=\dimen303
# \scratchbox=\box64
# \nofMPsegments=\count321
# \nofMParguments=\count322
# \everyMPshowfont=\toks37
# \MPscratchCnt=\count323
# \MPscratchDim=\dimen304
# \MPnumerator=\count324
# \makeMPintoPDFobject=\count325
# \everyMPtoPDFconversion=\toks38
# ) (/usr/share/texlive/texmf-dist/tex/latex/epstopdf-pkg/epstopdf-base.sty
# Package: epstopdf-base 2020-01-24 v2.11 Base part for package epstopdf
# Package epstopdf-base Info: Redefining graphics rule for `.eps' on input line 4
# 85.
#
# (/usr/share/texlive/texmf-dist/tex/latex/latexconfig/epstopdf-sys.cfg
# File: epstopdf-sys.cfg 2010/07/13 v1.3 Configuration of (r)epstopdf for TeX Liv
# e
# ))
# LaTeX Font Info:    Trying to load font information for U+msa on input line 16.
#
#
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsa.fd
# File: umsa.fd 2013/01/14 v3.01 AMS symbols A
# )
# LaTeX Font Info:    Trying to load font information for U+msb on input line 16.
#
#
# (/usr/share/texlive/texmf-dist/tex/latex/amsfonts/umsb.fd
# File: umsb.fd 2013/01/14 v3.01 AMS symbols B
# )
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.23 x_
#        1 + x_2 = 1
# I've inserted a begin-math/end-math symbol since I think
# you left one out. Proceed, with fingers crossed.
#
# ! Missing $ inserted.
# <inserted text>
#                 $
# l.41 \end{minipage}
#                    %
# I've inserted a begin-math/end-math symbol since I think
# you left one out. Proceed, with fingers crossed.
#
#
# Overfull \hbox (15.0pt too wide) in paragraph at lines 18--43
# [][]
#  []
#
# [1
#
# {/var/lib/texmf/fonts/map/pdftex/updmap/pdftex.map}] (./output.aux) )
# Here is how much of TeX's memory you used:
#  14213 strings out of 477975
#  301453 string characters out of 5839281
#  1850330 words of memory out of 5000000
#  34140 multiletter control sequences out of 15000+600000
#  513986 words of font info for 40 fonts, out of 8000000 for 9000
#  59 hyphenation exceptions out of 8191
#  87i,7n,90p,407b,109s stack positions out of 10000i,1000n,20000p,200000b,200000s
# </usr/shar
# e/texlive/texmf-dist/fonts/type1/public/amsfonts/cm/cmmi10.pfb></usr/share/texl
# ive/texmf-dist/fonts/type1/public/amsfonts/cm/cmr10.pfb></usr/share/texlive/tex
# mf-dist/fonts/type1/public/amsfonts/cm/cmr7.pfb>
# Output written on output.pdf (1 page, 26741 bytes).
# PDF statistics:
#  26 PDF objects out of 1000 (max. 8388607)
#  16 compressed objects within 1 object stream
#  0 named destinations out of 1000 (max. 500000)
#  13 words of extra memory for PDF output out of 10000 (max. 10000000)

# %% [markdown]
# ## Shortcascade helpers
#
# Normalize traces and build shortcascade lines.

# %%
from matrixlayout.shortcascade import normalize_backsub_trace, mk_shortcascade_lines

trace = {"base": "x_1 = 1", "steps": [("x_2 = 2", "x_2 = 2")] }
base, steps = normalize_backsub_trace(trace)
lines = mk_shortcascade_lines(trace)
base, steps, lines[:1]
# Out:
# ('x_1 = 1', [('x_2 = 2', 'x_2 = 2')], ['{\\ShortCascade%'])
